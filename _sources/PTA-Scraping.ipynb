# %% [markdown]
# # PTA-Scrapping

# %%
# !pip install requests
# !pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (2.25.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests) (4.0.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (4.6.3)

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
listPTA = []

for i in range(152,173):
  URL = "https://pta.trunojoyo.ac.id/c_search/byprod/10/" + str(i+1)
  req = requests.get(URL)
  soup = BeautifulSoup(req.text, 'html.parser')
  items = soup.find('div', {'id':'content_journal'})

  for it in items.findAll('li',{'data-cat':'#luxury'}):
    tempNama = it.find('span').text.strip('\n').replace('Penulis : ', '')
    link = it.find('a', 'gray button')['href']
    req2 = requests.get(link)
    soup2 = BeautifulSoup(req2.text, 'html.parser')
    abs = soup2.findAll('div')
    abstrak = soup2.find('p', {'align':'justify'}).text
  
    tempNIM = link.replace('https://pta.trunojoyo.ac.id/welcome/detail/', '')

    listPTA.append([it.a.text.strip('\n'), tempNIM, tempNama, abstrak])

# %%
listPTA_df = pd.DataFrame(listPTA, columns=['Judul', 'NIM', 'Penulis', 'Abstrak'])
listPTA_df
# Out:
#                                                 Judul           NIM  \
# 0   PENGARUH SELEKSI FITUR CHI SQUARE \nTERHADAP  ...  170411200135
# 1   SEGMENTASI TUMOR OTAK PADA CITRA MAGNETIC RESO...  150411100030
# 2   APLIKASI MONITORING & EVALUASI KEGIATAN ASRAMA...  150411100045
# 3   MONITORING CURAH HUJAN SECARA REAL TIME MENGGU...  140411100082
# 4   APLIKASI DIAGNOSA PENYAKIT GINJAL MENGGUNAKAN ...  140411100090
# ..                                                ...           ...
# 93  PENERAPAN ALGORITMA LONG-SHORT TERM MEMORY UNT...  160411100032
# 94  SISTEM PENCARIAN TEKS AL-QURAN TERJEMAHAN BERB...  160411100182
# 95  KLASIFIKASI KOMPLEKSITAS VISUAL CITRA SAMPAH M...  160411100077
# 96  IDENTIFIKASI BINER ATRIBUT PEJALAN KAKI MENGGU...  160411100084
# 97  DETEKSI OBJEK MANUSIA BERBASIS ONE STAGE DETEC...  160411100044
#
#                      Penulis  \
# 0         Emmilia Norhafifah
# 1      M. Sadewa Wicaksana W
# 2         NURHAYATI FITRIANI
# 3   Danny Wahyu Mailiffiandi
# 4        Hazmy Bagas Pradana
# ..                       ...
# 93     Rachmad Agung Pambudi
# 94          Nadila Hidayanti
# 95              Afni Sakinah
# 96   Friska Fatmawatiningrum
# 97               Dian Wibowo
#
#                                               Abstrak
# 0   Kanker Payudara adalah tumor ganas yang menyer...
# 1   Otak merupakan salah satu organ penting yang a...
# 2   Monitoring kegiatan asrama Universitas Trunojo...
# 3   Pada era globalisasi yang semakin maju perkemb...
# 4   ABSTRAK\nGinjal merupakan organ yang sangat pe...
# ..                                                ...
# 93  Investasi saham selama ini memiliki resiko ker...
# 94  Information Retrieval (IR) merupakan pengambil...
# 95  Klasifikasi citra merupakan proses pengelompok...
# 96  Identifikasi atribut pejalan kaki merupakan sa...
# 97  Topik deteksi objek telah menarik perhatian ya...
#
# [98 rows x 4 columns]

# %%
listPTA_df.to_csv('PTA_scraping.csv')
